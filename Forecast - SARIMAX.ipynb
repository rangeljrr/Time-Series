# %% [markdown]
# # Problem Understanding
# Across industries, organizations commonly use time series data, which means any information collected over a regular interval of time, in their operations. Examples include daily stock prices, energy consumption rates, social media engagement metrics and retail demand, among others. Analyzing time series data yields insights like trends, seasonal patterns and forecasts into future events that can help generate profits. For example, by understanding the seasonal trends in demand for retail products, companies can plan promotions to maximize sales throughout the year.
#
# When analyzing time series data, you should undertake a number of steps. First, you need to check for stationarity and autocorrelation. Stationarity is a way to measure if the data has structural patterns like seasonal trends. Autocorrelation occurs when future values in a time series linearly depend on past values. You need to check for both of these in time series data because they’re assumptions that are made by many widely used methods in time series analysis. For example, the autoregressive integrated moving average (ARIMA) method for forecasting time series assumes stationarity. Further, linear regression for time series forecasting assumes that the data has no autocorrelation. Before conducting these processes, then, you need to know if the data is viable for the analysis.
#
# During a time series analysis, you also need to perform trend decomposition and forecast future values. Decomposition allows you to visualize trends in your data, which is a great way to clearly explain their behavior. Finally, forecasting allows you to anticipate future events that can aid in decision making. You can use many different techniques for time series forecasting, but here, we will discuss the autoregressive integrated moving average (ARIMA).
#
# We will be working with publicly available airline passenger time series data
#
# __Passenger Data Source:__ https://github.com/AileenNielsen/TimeSeriesAnalysisWithPython/blob/master/data/AirPassengers.csv
# __CPI Data Source:__ https://fred.stlouisfed.org/series/CPIAUCSL

# %% [markdown]
# # Data Collection - Air Passengers

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.patches as mpatches
import numpy as np

import warnings
warnings.filterwarnings('ignore')


raw_data = pd.read_csv("_air_passengers.csv")

# Convert Month to datetime object
raw_data['Month'] = pd.to_datetime(raw_data['Month'], format='%Y-%m')

# Set index as date
raw_data.index = raw_data['Month']

# Drop column (extra memory no longer needed)
del raw_data['Month']

print(raw_data.head())
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# # Data Collection - CPI (FRED)

# %%
cpi_data = pd.read_csv("_cpi_fred.csv")

# Convert Month to datetime object
cpi_data['Month'] = pd.to_datetime(cpi_data['DATE'])

# Set index as date
cpi_data.index = cpi_data['Month']

# Drop column (extra memory no longer needed)
del cpi_data['DATE']
del cpi_data['Month']

print(cpi_data.head())
# Out:
#             CPIAUCSL
# Month
# 1947-01-01     21.48
# 1947-02-01     21.62
# 1947-03-01     22.00
# 1947-04-01     22.00
# 1947-05-01     21.95

# %% [markdown]
# # Preliminary Visual

# %%
def plot_config(title, axis, y_title, x_title):
    
    # Main Title
    #figure.suptitle('Categorical Plots')

    # Labels
    axis.set_title(title, fontsize=20)
    axis.set_xlabel(x_title, fontsize=15)
    axis.set_ylabel(y_title, fontsize=15)
    
    # Graph Spins
    # Plot 1: Config
    axis.spines['right'].set_visible(False)
    axis.spines['top'].set_visible(False)
    
    # Tickmark Sizes
    axis.tick_params(axis='both', which='major', labelsize=15)

def create_legend(legend_dict):
    list_patches = []
    for label in legend_dict.keys():
        color = legend_dict[label]
        list_patches.append(mpatches.Patch(color=color, label=label))
        plt.legend(handles=list_patches, loc='upper left', prop={'size': 15})

# %%
# Creating Figure
figure, axis = plt.subplots(figsize = (16,9))

# Time Histogram
plot_axis = axis
plot_config('Passenger Count', plot_axis,'','')

# Plot Actuals
plt.plot(raw_data['Passengers'], color='#1f77b4');

# Setting Legends
create_legend({'Original Data':'C0'})

# %% [markdown]
# # Stationarity - Visual
# Stationarity is a key part of time series analysis. Simply put, stationarity means that the manner in which time series data changes is constant. A stationary time series will not have any trends or seasonal patterns. You should check for stationarity because it not only makes modeling time series easier, but it is an underlying assumption in many time series methods. Specifically, stationarity is assumed for a wide variety of time series forecasting methods including autoregressive moving average (ARMA), ARIMA and Seasonal ARIMA (SARIMA).
#
# If the data is Stationary, then  the data doesn't have any disruptions in the data (pandemic, weather, disasters, etc.)
#
# We will use the Dickey Fuller test to check for stationarity in our data. This test will generate critical values and a p-value, which will allow us to accept or reject the null hypothesis that there is no stationarity. If we reject the null hypothesis, that means we accept the alternative, which states that there is stationarity.
#
# These values allow us to test the degree to which present values change with past values. If there is no stationarity in the data set, a change in present values will not cause a significant change in past values.
#
# Let’s test for stationarity in our airline passenger data. To start, let’s calculate a seven-month rolling mean:

# %%
# Taking the rolling mean
rolling_mean = raw_data.rolling(7).mean()
rolling_std = raw_data.rolling(7).std()

# Creating Figure
figure, axis = plt.subplots(figsize = (16,9))

# Time Histogram
plot_axis = axis
plot_config('Checking Stationarity', plot_axis,'','')

# Plot Actuals
plt.plot(raw_data['Passengers'], color='#1f77b4');
plt.plot(raw_data.index, rolling_mean['Passengers'], color="red")
plt.plot(raw_data.index, rolling_std['Passengers'], color="black")

# Setting Legends
create_legend({'Original Data':'C0', 'Rolling Mean':'red', 'Rolling Std':'black'})

# %% [markdown]
# # Stationarity - Dickey Fuller
# Next, let’s import the augmented Dickey-Fuller test from the statsmodels package. The documentation for the test can be found here.
#
# Next, let’s pass our data frame into the adfuller method. Here, we specify the autolag parameter as “AIC,” which means that the lag is chosen to minimize the information criterion:

# %%
from statsmodels.tsa.stattools import adfuller

adft = adfuller(raw_data['Passengers'],autolag="AIC")

# Adfuller results
print(pd.DataFrame({"Values":[adft[0],adft[1],adft[2],adft[3], adft[4]['1%'], adft[4]['5%'], adft[4]['10%']], 
                          "Metric":["Test Statistics","p-value","No. of lags used","Number of observations used", 
                                                        "critical value (1%)", "critical value (5%)", "critical value (10%)"]}))
# Out:
#        Values                       Metric
# 0    0.815369              Test Statistics
# 1    0.991880                      p-value
# 2   13.000000             No. of lags used
# 3  130.000000  Number of observations used
# 4   -3.481682          critical value (1%)
# 5   -2.884042          critical value (5%)
# 6   -2.578770         critical value (10%)

# %% [markdown]
# We can see that our data is not stationary from the fact that our p-value is greater than 5 percent and the test statistic is greater than the critical value. We can also draw these conclusions from inspecting the data, as we see a clear, increasing trend in the number of passengers.

# %% [markdown]
# # Autocorrelation
#
# Checking for autocorrelation in time series data is another important part of the analytic process. This is a measure of how correlated time series data is at a given point in time with past values, which has huge implications across many industries. For example, if our passenger data has strong autocorrelation, we can assume that high passenger numbers today suggest a strong likelihood that they will be high tomorrow as well.
#
# The Pandas data frame has an autocorrelation method that we can use to calculate the autocorrelation in our passenger data. Let’s do this for a one-month lag:

# %%
# Checking Autocorrelation with 1, 3, 6, and 9 months
print("One Month Lag: ", raw_data['Passengers'].autocorr(lag=1))
print("Three Month Lag: ", raw_data['Passengers'].autocorr(lag=3))
print("Six Month Lag: ", raw_data['Passengers'].autocorr(lag=6))
print("Nine Month Lag: ", raw_data['Passengers'].autocorr(lag=9))
# Out:
# One Month Lag:  0.9601946480498523
# Three Month Lag:  0.837394765081794
# Six Month Lag:  0.7839187959206183
# Nine Month Lag:  0.8278519011167601

# %% [markdown]
# We see that, even with a nine-month lag, the data is highly autocorrelated. This is further illustration of the short- and long-term trends in the data.

# %% [markdown]
# # Autocorrelation - ACF
#
# We can calculate the correlation for time series observations with observations with previous time steps, called lags. Because the correlation of the time series observations is calculated with values of the same series at previous times, this is called a serial correlation, or an autocorrelation.
#
# A plot of the autocorrelation of a time series by lag is called the AutoCorrelation Function, or the acronym ACF. This plot is sometimes called a correlogram or an autocorrelation plot.

# %%
from statsmodels.graphics.tsaplots import plot_acf
figure = plot_acf(raw_data['Passengers'])
figure.set_size_inches((16, 6))
plt.show()

# %% [markdown]
# # Autocorrelation - PACF
#
# A partial autocorrelation is a summary of the relationship between an observation in a time series with observations at prior time steps with the relationships of intervening observations removed.
#
# The autocorrelation for an observation and an observation at a prior time step is comprised of both the direct correlation and indirect correlations. These indirect correlations are a linear function of the correlation of the observation, with observations at intervening time steps.

# %%
from statsmodels.graphics.tsaplots import plot_pacf
figure = plot_pacf(raw_data['Passengers'])
figure.set_size_inches((16, 6))
plt.show()

# %% [markdown]
# # Interpret ACF and PACF
#
# (1) Look for tail off pattern in either ACF or PACF
# (2)If tail off at ACF → AR model → Cut off at PACF will provide order p for AR(p)
# (3)If tail off at PACF → MA model → Cut off at ACF will provide order q for MA(q)
# (4)Tail of at both ACF and PACF → ARMA model

# %% [markdown]
# # Time Series Decomposition
#
# Trend decomposition is another useful way to visualize the trends in time series data. To proceed, let’s import seasonal_decompose from the statsmodels package:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decomposition function
decompose = seasonal_decompose(raw_data['Passengers'],model='additive', period=7)

# Plotting time series decomposition
figure = decompose.plot()
figure.set_size_inches((14, 9))
figure.tight_layout()
plt.show()

# %% [markdown]
# From this plot, we can clearly see the increasing trend in number of passengers and the seasonality patterns in the rise and fall in values each year.

# %% [markdown]
# # Train Test Visual
#
# Time series forecasting allows us to predict future values in a time series given current and past data. Here, we will use the ARIMA method to forecast the number of passengers, which allows us to forecast future values in terms of a linear combination of past values. We will use the auto_arima package, which will allow us to forgo the time consuming process of hyperparameter tuning.
#
# First, let’s split our data for training and testing and visualize the split:

# %%
# Shift CPI data
print('Shift By:',raw_data.shape[0] - train_cutoff)
print('Note: Will need to shift without losing data')
# Out:
# Shift By: 14
# Note: Will need to shift without losing data

# %%
shift = raw_data.shape[0] - train_cutoff

# Merging data
main = pd.concat([raw_data, cpi_data],axis=1)

# Keeping max date of passenger data
main = main[main.index <= M]

m = main.index.min()
M = main.index.max()

# Create dummy empty dataframe, when shifting this will cause 0 data loss
dummy_lag_df = pd.DataFrame([['','']]*shift, columns = ['Passengers', 'CPIAUCSL'])
main = pd.concat([main,dummy_lag_df], axis = 0)

# Shifting CPI
main['CPIAUCSL'] = main['CPIAUCSL'].shift(shift)

# Creating new index (MS: Monthly first of month, M: Monthly end of month)
start = str(m)
end = str(M + pd.DateOffset(months=shift))
new_dates = pd.date_range(start=start, end=end, freq='MS', inclusive='both')

# Setting new index
main.index = new_dates

# Dropping N/As
main = main.dropna()

# %%
# 90% Train - 10% Test
train_cutoff = int(np.ceil(raw_data.shape[0] * .9))

train = main.iloc[0:train_cutoff]
test = main.iloc[train_cutoff:-shift]
validation = main.iloc[-14:]

# Creating Figure
figure, axis = plt.subplots(figsize = (16,9))

# Time Histogram
plot_axis = axis
plot_config('Train/Test Split', plot_axis,'','')

# Plot Train/Test
plt.plot(raw_data['Passengers'], color='black');
plt.plot(test['Passengers'], color='red');

# Setting Legends
create_legend({'Train':'black','Test':'red'})

# %% [markdown]
# The black line corresponds to our training data and the red line corresponds to our test data.
#
# Let’s import auto_arima from the pdmarima package, train our model and generate predictions:

# %% [markdown]
# # Auto Arima

# %%
from pmdarima.arima import auto_arima
target,exogenous_variable = ['Passengers','CPIAUCSL']
best_model = auto_arima(train[target], exog = train[exogenous_variable],
                           start_p=0, start_q=0,start_d=0,
                           max_p=5, max_q=5,max_d=5,
                           m=12, # Seasonal Parameter
                           start_P=0,start_D=0,start_Q=0,
                           max_P=5, max_D=5,max_Q=5,
                           seasonal=True,
                           #d=1, D=1,
                           trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=False)
# Out:
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=1000.326, Time=0.03 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=1001.372, Time=0.14 sec
#  ARIMA(0,0,0)(0,1,2)[12] intercept   : AIC=1002.765, Time=0.24 sec
#  ARIMA(0,0,0)(0,1,3)[12] intercept   : AIC=1004.404, Time=0.68 sec
#  ARIMA(0,0,0)(0,1,4)[12] intercept   : AIC=inf, Time=2.07 sec
#  ARIMA(0,0,0)(0,1,5)[12] intercept   : AIC=inf, Time=2.91 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=1001.191, Time=0.22 sec
#  ARIMA(0,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,0)(1,1,2)[12] intercept   : AIC=1002.258, Time=1.12 sec
#  ARIMA(0,0,0)(1,1,3)[12] intercept   : AIC=1003.139, Time=1.76 sec
#  ARIMA(0,0,0)(1,1,4)[12] intercept   : AIC=990.347, Time=2.84 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=1002.368, Time=0.43 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=0.88 sec
#  ARIMA(0,0,0)(2,1,2)[12] intercept   : AIC=inf, Time=1.10 sec
#  ARIMA(0,0,0)(2,1,3)[12] intercept   : AIC=inf, Time=2.19 sec
#  ARIMA(0,0,0)(3,1,0)[12] intercept   : AIC=1004.216, Time=0.86 sec
#  ARIMA(0,0,0)(3,1,1)[12] intercept   : AIC=996.248, Time=1.82 sec
#  ARIMA(0,0,0)(3,1,2)[12] intercept   : AIC=inf, Time=1.90 sec
#  ARIMA(0,0,0)(4,1,0)[12] intercept   : AIC=986.126, Time=2.12 sec
#  ARIMA(0,0,0)(4,1,1)[12] intercept   : AIC=987.118, Time=3.18 sec
#  ARIMA(0,0,0)(5,1,0)[12] intercept   : AIC=inf, Time=4.25 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=944.733, Time=0.07 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=944.601, Time=0.18 sec
#  ARIMA(0,0,1)(0,1,2)[12] intercept   : AIC=946.407, Time=0.33 sec
#  ARIMA(0,0,1)(0,1,3)[12] intercept   : AIC=948.159, Time=0.57 sec
#  ARIMA(0,0,1)(0,1,4)[12] intercept   : AIC=944.132, Time=1.85 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=944.449, Time=0.23 sec
#  ARIMA(0,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(0,0,1)(1,1,2)[12] intercept   : AIC=948.405, Time=0.57 sec
#  ARIMA(0,0,1)(1,1,3)[12] intercept   : AIC=948.117, Time=2.51 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=946.393, Time=0.63 sec
#  ARIMA(0,0,1)(2,1,1)[12] intercept   : AIC=948.390, Time=0.46 sec
#  ARIMA(0,0,1)(2,1,2)[12] intercept   : AIC=inf, Time=1.34 sec
#  ARIMA(0,0,1)(3,1,0)[12] intercept   : AIC=948.352, Time=1.33 sec
#  ARIMA(0,0,1)(3,1,1)[12] intercept   : AIC=950.389, Time=1.18 sec
#  ARIMA(0,0,1)(4,1,0)[12] intercept   : AIC=941.967, Time=2.46 sec
#  ARIMA(0,0,2)(0,1,0)[12] intercept   : AIC=907.649, Time=0.11 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=909.108, Time=0.23 sec
#  ARIMA(0,0,2)(0,1,2)[12] intercept   : AIC=911.020, Time=0.53 sec
#  ARIMA(0,0,2)(0,1,3)[12] intercept   : AIC=912.923, Time=0.92 sec
#  ARIMA(0,0,2)(1,1,0)[12] intercept   : AIC=909.072, Time=0.33 sec
#  ARIMA(0,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(0,0,2)(1,1,2)[12] intercept   : AIC=913.020, Time=0.67 sec
#  ARIMA(0,0,2)(2,1,0)[12] intercept   : AIC=910.936, Time=0.63 sec
#  ARIMA(0,0,2)(2,1,1)[12] intercept   : AIC=912.947, Time=0.77 sec
#  ARIMA(0,0,2)(3,1,0)[12] intercept   : AIC=912.540, Time=1.69 sec
#  ARIMA(0,0,3)(0,1,0)[12] intercept   : AIC=893.891, Time=0.15 sec
#  ARIMA(0,0,3)(0,1,1)[12] intercept   : AIC=894.495, Time=0.26 sec
#  ARIMA(0,0,3)(0,1,2)[12] intercept   : AIC=896.392, Time=0.48 sec
#  ARIMA(0,0,3)(1,1,0)[12] intercept   : AIC=894.423, Time=0.35 sec
#  ARIMA(0,0,3)(1,1,1)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(0,0,3)(2,1,0)[12] intercept   : AIC=896.379, Time=0.83 sec
#  ARIMA(0,0,4)(0,1,0)[12] intercept   : AIC=894.411, Time=0.22 sec
#  ARIMA(0,0,4)(0,1,1)[12] intercept   : AIC=895.209, Time=0.45 sec
#  ARIMA(0,0,4)(1,1,0)[12] intercept   : AIC=895.115, Time=0.40 sec
#  ARIMA(0,0,5)(0,1,0)[12] intercept   : AIC=893.955, Time=0.25 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=889.687, Time=0.06 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=890.187, Time=0.16 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=891.449, Time=0.37 sec
#  ARIMA(1,0,0)(0,1,3)[12] intercept   : AIC=893.280, Time=0.77 sec
#  ARIMA(1,0,0)(0,1,4)[12] intercept   : AIC=893.637, Time=1.51 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=889.966, Time=0.23 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=889.127, Time=1.28 sec
#  ARIMA(1,0,0)(1,1,3)[12] intercept   : AIC=890.692, Time=2.48 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=891.479, Time=0.62 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=1.35 sec
#  ARIMA(1,0,0)(2,1,2)[12] intercept   : AIC=inf, Time=1.47 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=893.266, Time=1.18 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=891.611, Time=2.77 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=893.300, Time=1.91 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=889.738, Time=0.09 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=890.597, Time=0.22 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=890.988, Time=0.56 sec
#  ARIMA(1,0,1)(0,1,3)[12] intercept   : AIC=892.545, Time=1.04 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=890.342, Time=0.34 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=886.822, Time=1.55 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=890.955, Time=0.77 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=888.036, Time=1.50 sec
#  ARIMA(1,0,1)(3,1,0)[12] intercept   : AIC=892.218, Time=1.59 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=887.310, Time=0.15 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=888.164, Time=0.38 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=889.205, Time=0.90 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=887.974, Time=0.45 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(1,0,2)(2,1,0)[12] intercept   : AIC=889.167, Time=0.89 sec
#  ARIMA(1,0,3)(0,1,0)[12] intercept   : AIC=887.873, Time=0.17 sec
#  ARIMA(1,0,3)(0,1,1)[12] intercept   : AIC=889.128, Time=0.41 sec
#  ARIMA(1,0,3)(1,1,0)[12] intercept   : AIC=888.982, Time=0.49 sec
#  ARIMA(1,0,4)(0,1,0)[12] intercept   : AIC=889.606, Time=0.25 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=888.876, Time=0.07 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=889.889, Time=0.21 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=889.888, Time=0.48 sec
#  ARIMA(2,0,0)(0,1,3)[12] intercept   : AIC=891.324, Time=1.00 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=889.639, Time=0.24 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=885.400, Time=1.56 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=889.771, Time=0.71 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=885.885, Time=1.47 sec
#  ARIMA(2,0,0)(3,1,0)[12] intercept   : AIC=890.836, Time=1.25 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=888.718, Time=0.15 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=889.982, Time=0.37 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=890.155, Time=0.88 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=889.794, Time=0.60 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=889.930, Time=0.87 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=888.534, Time=0.22 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=889.653, Time=0.63 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=889.489, Time=0.62 sec
#  ARIMA(2,0,3)(0,1,0)[12] intercept   : AIC=889.778, Time=0.29 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=887.458, Time=0.13 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=888.609, Time=0.30 sec
#  ARIMA(3,0,0)(0,1,2)[12] intercept   : AIC=889.266, Time=0.73 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=888.432, Time=0.42 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=889.126, Time=0.95 sec
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=889.383, Time=0.21 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=890.569, Time=0.43 sec
#  ARIMA(3,0,1)(1,1,0)[12] intercept   : AIC=890.399, Time=0.60 sec
#  ARIMA(3,0,2)(0,1,0)[12] intercept   : AIC=888.368, Time=0.29 sec
#  ARIMA(4,0,0)(0,1,0)[12] intercept   : AIC=889.312, Time=0.12 sec
#  ARIMA(4,0,0)(0,1,1)[12] intercept   : AIC=890.527, Time=0.34 sec
#  ARIMA(4,0,0)(1,1,0)[12] intercept   : AIC=890.362, Time=0.45 sec
#  ARIMA(4,0,1)(0,1,0)[12] intercept   : AIC=891.212, Time=0.30 sec
#  ARIMA(5,0,0)(0,1,0)[12] intercept   : AIC=890.693, Time=0.20 sec
#
# Best model:  ARIMA(2,0,0)(1,1,2)[12] intercept
# Total fit time: 105.589 seconds

# %% [markdown]
# # Best Components

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

order = best_model.order
seasonal_order = best_model.seasonal_order
print('Best Order:', order)
print('Best Seasonal Order:', seasonal_order)

sarimax = SARIMAX(train[target].astype(float), exog = train[exogenous_variable].astype(float),
                  order=order , seasonal_order=seasonal_order).fit(disp=False)

main['Test Forecast'] = sarimax.forecast(14,exog = test[exogenous_variable].astype(float))
# Out:
# Best Order: (2, 0, 0)
# Best Seasonal Order: (1, 1, 2, 12)

# %% [markdown]
# Our predictions are shown in green and the actual values are shown in orange.
#
# Finally, let’s calculate root mean squared error (RMSE):

# %% [markdown]
# # Test Validation

# %%
# Creating Figure
figure, axis = plt.subplots(figsize = (16,9))

# Time Histogram
plot_axis = axis
plot_config('Test Validation', plot_axis,'','')

# Plot Train/Test
plt.plot(raw_data['Passengers'], color='black');
plt.plot(test['Passengers'], color='red');
plt.plot(main['Test Forecast'], color='green');

# Setting Legends
create_legend({'Train':'black','Test':'red', 'Pred':'darkgreen'})

# %% [markdown]
# # Test Validation - RMSE

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse = sqrt(mean_squared_error(test['Passengers'],main['Passenger Forecast'].dropna()))
mape = np.mean(np.abs(test['Passengers'] - main['Passenger Forecast'].dropna()) / test['Passengers'])
print("RMSE: ", rmse)
print("MAPE: ", mape)
# Out:
# RMSE:  17.217582743569245
# MAPE:  0.03286682786323643

# %% [markdown]
# # 14mo Forecast

# %%
sarimax = SARIMAX(main.iloc[0:-14][target].astype(float), exog = main.iloc[0:-14][exogenous_variable].astype(float),
                  order=order , seasonal_order=seasonal_order).fit(disp=False)

main['14mo Forecast'] = sarimax.forecast(14,exog = main.iloc[-14:][exogenous_variable].astype(float))

# Creating Figure
figure, axis = plt.subplots(figsize = (16,9))

# Time Histogram
plot_axis = axis
plot_config('14mo Forecast', plot_axis,'','')

# Plot Train/Test
plt.plot(raw_data['Passengers'], color='C0');
plt.plot(main['14mo Forecast'], color='green', linestyle='--');

# Setting Legends
create_legend({'Original':'C0','14mo Forecast':'green'})

# %% [markdown]
# # Final Results

# %%
main['14mo Forecast'].dropna()
# Out:
# 1961-01-01    446.031577
# 1961-02-01    417.898576
# 1961-03-01    459.421226
# 1961-04-01    485.206242
# 1961-05-01    501.620142
# 1961-06-01    566.853060
# 1961-07-01    654.473344
# 1961-08-01    646.244050
# 1961-09-01    539.224585
# 1961-10-01    485.167903
# 1961-11-01    417.167431
# 1961-12-01    459.614816
# 1962-01-01    474.620222
# 1962-02-01    443.616687
# Freq: MS, Name: 14mo Forecast, dtype: float64
